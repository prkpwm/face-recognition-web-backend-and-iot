# %%
import dlib

# %%
import joblib

# %%
predictor_path = "../model/face_landmarks68.dat"
face_rec_model_path = "../model/face_recognition.dat"
detector = dlib.get_frontal_face_detector()  # หาใบหน้าคน
sp = dlib.shape_predictor(predictor_path)
facerec = dlib.face_recognition_model_v1(face_rec_model_path)

# %%
import cv2

# %%
img = cv2.imread('image_no_crop/076dfc97d78147a2a4e77697019c2f14.bmp')

# %%
import ml_lib

# %%
c = ml_lib.face_prediction('076dfc97d78147a2a4e77697019c2f14.bmp')
# Out:
# path /home/recognition/Documents/backend/IoT/scr
# image shape:  (540, 288, 3)
# dept:  rectangles[[(94, 154) (273, 333)]]
# convert img
# cropped
# uuid image 410df4837d744600b1bacf874630b35b
# load_model_svm_classification /home/recognition/Documents/backend/IoT/scr
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-a0d7880bc9c4> in <module>
# ----> 1 c = ml_lib.face_prediction('076dfc97d78147a2a4e77697019c2f14.bmp')
#
# ~/Documents/backend/IoT/scr/ml_lib.py in face_prediction(image_name)
#     200         face_descriptor = face_descriptor.reshape(1, -1)
#     201         # load model
# --> 202         model = load_model_svm_classification()
#     203         # prediction
#     204         svm_proba = model.predict_proba(face_descriptor)
#
# ~/Documents/backend/IoT/scr/ml_lib.py in load_model_svm_classification()
#     142 def load_model_svm_classification():
#     143     print('load_model_svm_classification',os.getcwd())
# --> 144     model = load(open('../model/svm_face_recognition.sav', 'rb'))
#     145     return model
#     146
#
# ~/.local/lib/python3.6/site-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     573         filename = getattr(fobj, 'name', '')
#     574         with _read_fileobject(fobj, filename, mmap_mode) as fobj:
# --> 575             obj = _unpickle(fobj)
#     576     else:
#     577         with open(filename, 'rb') as f:
#
# ~/.local/lib/python3.6/site-packages/joblib/numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     502     obj = None
#     503     try:
# --> 504         obj = unpickler.load()
#     505         if unpickler.compat_mode:
#     506             warnings.warn("The file '%s' has been generated with a "
#
# /usr/lib/python3.6/pickle.py in load(self)
#    1048                     raise EOFError
#    1049                 assert isinstance(key, bytes_types)
# -> 1050                 dispatch[key[0]](self)
#    1051         except _Stop as stopinst:
#    1052             return stopinst.value
#
# /usr/lib/python3.6/pickle.py in load_global(self)
#    1336         module = self.readline()[:-1].decode("utf-8")
#    1337         name = self.readline()[:-1].decode("utf-8")
# -> 1338         klass = self.find_class(module, name)
#    1339         self.append(klass)
#    1340     dispatch[GLOBAL[0]] = load_global
#
# /usr/lib/python3.6/pickle.py in find_class(self, module, name)
#    1386             elif module in _compat_pickle.IMPORT_MAPPING:
#    1387                 module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1388         __import__(module, level=0)
#    1389         if self.proto >= 4:
#    1390             return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'sklearn.svm._classes'
