# %%
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")

# %%
mydb = myclient["iHomeWhiz"]

# %%
mycol_member = mydb["member"]

# %%
def get_data1():
    mydoc = mycol_member.find({"activated": True}, {"info.user_id":1,"data":1})
    return list(mydoc)
def get_data2():
    mydoc = mycol_member.find({"activated": True}, {"data":1})
    return list(mydoc)

# %%
data_userid = get_data1()
# data_train = get_data2()

# %%
data_train_list = list()
data_label = list()
for dt in data_userid:
    data_train_list.append(dt['data'])
    data_label.append(dt['info']['user_id'])
#     data_train_list.append(dt)
#     print(dt)
print(data_label)
# Out:
# ['1', '2', '6', '7', '8']

# %%
dats_train = list()
dats_label = list()

for i,train in enumerate(data_train_list):
    for sub_train in train:
        dats_train.append(sub_train)
#         print(sub_train)
# Out:
# [-0.172620177268982, 0.13376347720623, 0.114959634840488, -0.049773633480072, -0.0769269019365311, -0.0542526505887508, 0.05539595708251, -0.141993492841721, 0.167823523283005, -0.0874003171920776, 0.260316014289856, -0.0198687463998795, -0.200764358043671, -0.196703538298607, 0.0123757869005203, 0.165163606405258, -0.103140212595463, -0.164809823036194, -0.0794328674674034, -0.0450760200619698, 0.0359659790992737, -0.103779137134552, 0.00837972201406956, 0.0780816078186035, -0.0656864866614342, -0.347773134708405, -0.0825597047805786, -0.0966160893440247, 0.0705371275544167, -0.0870161801576614, -0.0424430444836617, 0.0497239716351032, -0.256460070610046, -0.0802204161882401, -0.0735311359167099, 0.0872514024376869, 0.059649970382452, -0.0438105165958405, 0.14725050330162, -0.0663372576236725, -0.223375797271729, -0.0120619237422943, 0.0383024662733078, 0.171550020575523, 0.200828731060028, 0.00399140268564224, 0.0475158505141735, -0.0489658713340759, 0.0954017862677574, -0.12724548
# ...

# %%
data_train_list
# Out:
# [[[-0.172620177268982,
#    0.13376347720623,
#    0.114959634840488,
#    -0.049773633480072,
#    -0.0769269019365311,
#    -0.0542526505887508,
#    0.05539595708251,
#    -0.141993492841721,
#    0.167823523283005,
#    -0.0874003171920776,
#    0.260316014289856,
#    -0.0198687463998795,
#    -0.200764358043671,
#    -0.196703538298607,
#    0.0123757869005203,
#    0.165163606405258,
#    -0.103140212595463,
#    -0.164809823036194,
#    -0.0794328674674034,
#    -0.0450760200619698,
#    0.0359659790992737,
#    -0.103779137134552,
#    0.00837972201406956,
#    0.0780816078186035,
#    -0.0656864866614342,
#    -0.347773134708405,
#    -0.0825597047805786,
#    -0.0966160893440247,
#    0.0705371275544167,
#    -0.0870161801576614,
#    -0.0424430444836617,
#    0.0497239716351032,
#    -0.256460070610046,
#    -0.0802204161882401,
#    -0.0735311359167099,
#    0.0872514024376869,
#    0.059649970382452,
#    -0.0438105165958405,
#    0.14725050330162,
# ...

# %%
dats_nickname
# Out:
# ['1', '2', '6', '7', '8']

# %%
data_train = []
label_train = []
for nickname in dats_nickname:
    for i,dats in enumerate(dats_data):
        data_train.append(dats)
#         print(data_train[0])
        label_train.append(nickname)
#         print(nickname)
    print('-----------------')
# Out:
# [[-0.172620177268982, 0.13376347720623, 0.114959634840488, -0.049773633480072, -0.0769269019365311, -0.0542526505887508, 0.05539595708251, -0.141993492841721, 0.167823523283005, -0.0874003171920776, 0.260316014289856, -0.0198687463998795, -0.200764358043671, -0.196703538298607, 0.0123757869005203, 0.165163606405258, -0.103140212595463, -0.164809823036194, -0.0794328674674034, -0.0450760200619698, 0.0359659790992737, -0.103779137134552, 0.00837972201406956, 0.0780816078186035, -0.0656864866614342, -0.347773134708405, -0.0825597047805786, -0.0966160893440247, 0.0705371275544167, -0.0870161801576614, -0.0424430444836617, 0.0497239716351032, -0.256460070610046, -0.0802204161882401, -0.0735311359167099, 0.0872514024376869, 0.059649970382452, -0.0438105165958405, 0.14725050330162, -0.0663372576236725, -0.223375797271729, -0.0120619237422943, 0.0383024662733078, 0.171550020575523, 0.200828731060028, 0.00399140268564224, 0.0475158505141735, -0.0489658713340759, 0.0954017862677574, -0.1272454
# ...

# %%
len(data_train[2])
# data_train[0]
for dats_train in data_train:
    print(dats_train[0])
# Out:
# 5

# %%
list_data_nick_name = list()
list_data__train = list()

# %%
for member in member_collections:
    list_data_nick_name.append(member['info']['nick_name'])
    list_data_train.append(member['data'])

# %%
list_data_nick_name
# Out:
# ['Hung', 'Por', 'Noey', 'Ton', 'Aum']

# %%
len(list_data_train[2])
# Out:
# 5

# %%
for data in list_data_train:
    print(data)
# Out:
# [[-0.172620177268982, 0.13376347720623, 0.114959634840488, -0.049773633480072, -0.0769269019365311, -0.0542526505887508, 0.05539595708251, -0.141993492841721, 0.167823523283005, -0.0874003171920776, 0.260316014289856, -0.0198687463998795, -0.200764358043671, -0.196703538298607, 0.0123757869005203, 0.165163606405258, -0.103140212595463, -0.164809823036194, -0.0794328674674034, -0.0450760200619698, 0.0359659790992737, -0.103779137134552, 0.00837972201406956, 0.0780816078186035, -0.0656864866614342, -0.347773134708405, -0.0825597047805786, -0.0966160893440247, 0.0705371275544167, -0.0870161801576614, -0.0424430444836617, 0.0497239716351032, -0.256460070610046, -0.0802204161882401, -0.0735311359167099, 0.0872514024376869, 0.059649970382452, -0.0438105165958405, 0.14725050330162, -0.0663372576236725, -0.223375797271729, -0.0120619237422943, 0.0383024662733078, 0.171550020575523, 0.200828731060028, 0.00399140268564224, 0.0475158505141735, -0.0489658713340759, 0.0954017862677574, -0.1272454
# ...

# %%
x = mycol.find({"name":"pepomomos"})[0]

# %%
x = mycol.find()[1]

# %%
print(x)
# Out:
# {'_id': ObjectId('5f47872ad2dd1a94facc15e7'), 'name': 'pepomomos', 'age': 24.0}

# %%
mycol = mydb["lelalomos_collection2"]

# %%
mycol.find()[0]
# Out:
# {'_id': ObjectId('5f478b37d2dd1a94facc15e8'), 'count': 21.0, 'post': 22.0}

# %%
for data in mycol.find():
    print(data)
# Out:
# {'_id': ObjectId('5f478b37d2dd1a94facc15e8'), 'count': 21.0, 'post': 22.0}
# {'_id': ObjectId('5f478b53d2dd1a94facc15e9'), 'count': 52.0, 'post': 30.0}
# {'_id': ObjectId('5f478bfaf401984398fea74b'), 'count': 85, 'post': 68}

# %%
mycol.insert({'count':85,'post':68})
# Out:
# C:\Users\mop_2\AppData\Local\Continuum\anaconda3\envs\cnn\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ObjectId('5f478bfaf401984398fea74b')
